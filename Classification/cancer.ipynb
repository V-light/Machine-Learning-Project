# %%
import pandas as pd
df = pd.read_csv("cancer.csv")
df.sample(20)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 303    892657         B       10.490         18.61           66.86      334.3
# 427     90745         B       10.800         21.98           68.79      359.9
# 407    905190         B       12.850         21.37           82.63      514.5
# 95      86208         M       20.260         23.03          132.40     1264.0
# 298    892214         B       14.260         18.17           91.22      633.1
# 486    913102         B       14.640         16.85           94.21      666.0
# 125     86561         B       13.850         17.21           88.44      588.7
# 25     852631         M       17.140         16.40          116.00      912.7
# 133    867387         B       15.710         13.93          102.00      761.7
# 177  87281702         M       16.460         20.11          109.30      832.9
# 357    901028         B       13.870         16.21           88.52      593.7
# ...

# %%
df.describe(include = "object")
# Out:
#        diagnosis
# count        569
# unique         2
# top            B
# freq         357

# %%
df["diagnosis"].replace(["M", "B"], [1 ,0], inplace = True)

# %%
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1       17.990         10.38          122.80
# 1      842517          1       20.570         17.77          132.90
# 2    84300903          1       19.690         21.25          130.00
# 3    84348301          1       11.420         20.38           77.58
# 4    84358402          1       20.290         14.34          135.10
# 5      843786          1       12.450         15.70           82.57
# 6      844359          1       18.250         19.98          119.60
# 7    84458202          1       13.710         20.83           90.20
# 8      844981          1       13.000         21.82           87.50
# 9    84501001          1       12.460         24.04           83.97
# 10     845636          1       16.020         23.24          102.70
# 11   84610002          1       15.780         17.89          103.60
# 12     846226          1       19.170         24.80          132.40
# ...

# %%
# from sklearn.linear_model import LogisticRegression
# model = LogisticRegression()
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=300, random_state=1)
# from xgboost import XGBClassifier
# model = XGBClassifier(n_estimators=484,eta =0.4)

# %%
y = df["diagnosis"]
X = df.drop(["diagnosis","Unnamed: 32"], axis = 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2, random_state = 16)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=None,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.9736842105263158

# %%
from sklearn.metrics import confusion_matrix

# %%
y_prd = model.predict(X_test)

# %%
confusion_matrix(y_test, y_prd)
# Out:
# array([[72,  1],
#        [ 2, 39]], dtype=int64)

# %%
# from sklearn.model_selection import RandomizedSearchCV , GridSearchCV
# import numpy as np
# model = RandomForestClassifier()

# random_grid = {'n_estimators': [int(x) for x in np.linspace(start=400, stop=500, num = 20)]}
# # rf_random = RandomizedSearchCV(estimator = model , param_distributions =random_grid, cv =4)
# rf_random=GridSearchCV(model, random_grid , cv= 5)

# rf_random.fit(X_train, y_train)
# print(rf_random.best_score_)
# rf_random.best_params_

# %%
df.describe()
# Out:
#                  id   diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  5.690000e+02  569.000000   569.000000    569.000000      569.000000
# mean   3.037183e+07    0.372583    14.127292     19.289649       91.969033
# std    1.250206e+08    0.483918     3.524049      4.301036       24.298981
# min    8.670000e+03    0.000000     6.981000      9.710000       43.790000
# 25%    8.692180e+05    0.000000    11.700000     16.170000       75.170000
# 50%    9.060240e+05    0.000000    13.370000     18.840000       86.240000
# 75%    8.813129e+06    1.000000    15.780000     21.800000      104.100000
# max    9.113205e+08    1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# ...

# %%
# df["diagnosis"][df["radius_mean"]>15]

# %%
def radius(s1):
    var =0
    if(s1>15):
        var = 1
    else:
        var =0
    return var

# %%
#  df["radius_title"] =df["radius_mean"].apply(radius)

# %%
# df["radius_title"]
